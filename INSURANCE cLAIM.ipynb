# %% [markdown]
# # Insurance Claim

# %%
#Importing necessary libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
df.columns.to_list()
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_bind_date',
#  'policy_state',
#  'policy_csl',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'capital-gains',
#  'capital-loss',
#  'incident_date',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_location',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'property_damage',
#  'bodily_injuries',
#  'witnesses',
#  'police_report_available',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_make',
#  'auto_model',
#  'auto_year',
#  'fraud_reported',
#  '_c39']

# %%
#There are 1000 rows and 40 columns are present

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %%
df=df.replace('?',np.NaN)

# %%
df['property_damage'].fillna(df['property_damage'].mode()[0],inplace=True)
df['police_report_available'].fillna(df['police_report_available'].mode()[0],inplace=True)
df['collision_type'].fillna(df['collision_type'].mode()[0],inplace=True)

# %%
#Dropping the unncecessary columns

# %%
df
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       17-10-2014           OH    250/500
# 1                   228   42       27-06-2006           IN    250/500
# 2                   134   29       06-09-2000           OH    100/300
# 3                   256   41       25-05-1990           IL    250/500
# 4                   228   44       06-06-2014           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       16-07-1991           OH   500/1000
# 996                 285   41       05-01-2014           IL    100/300
# 997                 130   34       17-02-2003           OH    250/500
# 998                 458   62       18-11-2011           IL   500/1000
# 999                 456   60       11-11-1996           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit insured_sex  \
# 0                 1000                1406.91               0        MALE
# 1                 2000                1197.22         5000000        MALE
# 2                 2000                1413.14         5000000      FEMALE
# 3                 2000                1415.74         6000000      FEMALE
# 4                 1000                1583.91         6000000        MALE
# ..                 ...                    ...             ...         ...
# 995               1000                1310.80               0      FEMALE
# 996               1000                1436.79               0      FEMALE
# 997                500                1383.49         3000000      FEMALE
# 998               2000                1356.92         5000000        MALE
# 999               1000                 766.19               0      FEMALE
#
#     insured_education_level  ... witnesses police_report_available  \
# 0                        MD  ...         2                     YES
# 1                        MD  ...         0                      NO
# 2                       PhD  ...         3                      NO
# 3                       PhD  ...         2                      NO
# 4                 Associate  ...         1                      NO
# ..                      ...  ...       ...                     ...
# 995                 Masters  ...         1                      NO
# 996                     PhD  ...         3                      NO
# 997                 Masters  ...         3                     YES
# 998               Associate  ...         1                     YES
# 999               Associate  ...         3                      NO
#
#     total_claim_amount  injury_claim  property_claim vehicle_claim  \
# 0                71610          6510           13020         52080
# 1                 5070           780             780          3510
# 2                34650          7700            3850         23100
# 3                63400          6340            6340         50720
# 4                 6500          1300             650          4550
# ..                 ...           ...             ...           ...
# 995              87200         17440            8720         61040
# 996             108480         18080           18080         72320
# 997              67500          7500            7500         52500
# 998              46980          5220            5220         36540
# 999               5060           460             920          3680
#
#       auto_make auto_model auto_year fraud_reported
# 0          Saab        92x      2004              Y
# 1      Mercedes       E400      2007              Y
# 2         Dodge        RAM      2007              N
# 3     Chevrolet      Tahoe      2014              Y
# 4        Accura        RSX      2009              N
# ..          ...        ...       ...            ...
# 995       Honda     Accord      2006              N
# 996  Volkswagen     Passat      2015              N
# 997      Suburu    Impreza      1996              N
# 998        Audi         A5      1998              N
# 999    Mercedes       E400      2007              N
#
# [1000 rows x 36 columns]

# %%
df['CSL_Personal']=df.policy_csl.str.split('/',expand=True)[0]
df['CSL_Accidental']=df.policy_csl.str.split('/',expand=True)[1]

# %%
df.drop("policy_csl",axis=1,inplace=True)

# %%
#converting date columns to datetime type

# %%
df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
df['policy_bind_day'] = df['policy_bind_date'].dt.day
df['policy_bind_month'] = df['policy_bind_date'].dt.month
df['policy_bind_year'] = df['policy_bind_date'].dt.year

# Extracting Day, Month and Year column from incident_date
df['incident_day'] = df['incident_date'].dt.day
df['incident_month'] = df['incident_date'].dt.month
df['incident_year'] = df['incident_date'].dt.year

# %%
df.drop(['policy_bind_date','incident_date'],axis=1,inplace=True)

# %%
df.drop(['incident_year'],axis=1,inplace=True)

# %%
# Lets extract age of the vehicle from auto_year by subtracting it from the year 2018
df['Automobile_Age']=2015 - df['auto_year']
# Droping auto year column
df.drop("auto_year",axis=1,inplace=True)

# %%
Category = ['policy_state',  'insured_sex', 'insured_education_level', 'insured_occupation', 
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted','incident_state', 'incident_city', 'property_damage','police_report_available',
            'auto_make','auto_model', 'fraud_reported']
    
Numerical = ['months_as_customer','CSL_Personal','CSL_Accidental', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age','policy_annual_premium']

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int32: ['policy_bind_day', 'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month'], int64: ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age'], float64: ['policy_annual_premium'], object: ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']}

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_deductable  \
# count         1000.000000  1000.000000        1000.000000
# mean           203.954000    38.948000        1136.000000
# std            115.113174     9.140287         611.864673
# min              0.000000    19.000000         500.000000
# 25%            115.750000    32.000000         500.000000
# 50%            199.500000    38.000000        1000.000000
# 75%            276.250000    44.000000        2000.000000
# max            479.000000    64.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit  capital-gains   capital-loss  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06   25126.100000  -26793.700000
# std               244.167395    2.297407e+06   27872.187708   28104.096686
# min               433.330000   -1.000000e+06       0.000000 -111100.000000
# 25%              1089.607500    0.000000e+00       0.000000  -51500.000000
# 50%              1257.200000    0.000000e+00       0.000000  -23250.000000
# 75%              1415.695000    0.000000e+00   51025.000000       0.000000
# max              2047.590000    1.000000e+07  100500.000000       0.000000
#
#        incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# count               1000.000000                   1000.00000      1000.000000
# mean                  11.644000                      1.83900         0.992000
# std                    6.951373                      1.01888         0.820127
# min                    0.000000                      1.00000         0.000000
# 25%                    6.000000                      1.00000         0.000000
# 50%                   12.000000                      1.00000         1.000000
# 75%                   17.000000                      3.00000         2.000000
# max                   23.000000                      4.00000         2.000000
#
#        ...  total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# count  ...          1000.00000   1000.000000     1000.000000    1000.000000
# mean   ...         52761.94000   7433.420000     7399.570000   37928.950000
# std    ...         26401.53319   4880.951853     4824.726179   18886.252893
# min    ...           100.00000      0.000000        0.000000      70.000000
# 25%    ...         41812.50000   4295.000000     4445.000000   30292.500000
# 50%    ...         58055.00000   6775.000000     6750.000000   42100.000000
# 75%    ...         70592.50000  11305.000000    10885.000000   50822.500000
# max    ...        114920.00000  21450.000000    23670.000000   79560.000000
#
#        policy_bind_day  policy_bind_month  policy_bind_year  incident_day  \
# count      1000.000000        1000.000000       1000.000000   1000.000000
# mean         15.448000           6.559000       2001.604000     14.995000
# std           8.808001           3.499824          7.360391      8.670995
# min           1.000000           1.000000       1990.000000      1.000000
# 25%           8.000000           3.000000       1995.000000      7.750000
# 50%          16.000000           7.000000       2002.000000     15.000000
# 75%          23.000000          10.000000       2008.000000     22.000000
# max          31.000000          12.000000       2015.000000     31.000000
#
#        incident_month  Automobile_Age
# count     1000.000000     1000.000000
# mean         1.496000        9.897000
# std          0.523697        6.015861
# min          1.000000        0.000000
# 25%          1.000000        5.000000
# 50%          1.000000       10.000000
# 75%          2.000000       15.000000
# max          3.000000       20.000000
#
# [8 rows x 21 columns]

# %%
#By seeing above table the outliers are present in the data and skewness is also there

# %%
df[Category].describe().T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# </style>
# <table id="T_661f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_661f0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_661f0_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_661f0_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_661f0_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_661f0_level0_row0" class="row_heading level0 row0" >policy_state</th>
#       <td id="T_661f0_row0_col0" class="data row0 col0" >1000</td>
#       <td id="T_661f0_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_661f0_row0_col2" class="data row0 col2" >OH</td>
#       <td id="T_661f0_row0_col3" class="data row0 col3" >352</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row1" class="row_heading level0 row1" >insured_sex</th>
#       <td id="T_661f0_row1_col0" class="data row1 col0" >1000</td>
#       <td id="T_661f0_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_661f0_row1_col2" class="data row1 col2" >FEMALE</td>
#       <td id="T_661f0_row1_col3" class="data row1 col3" >537</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row2" class="row_heading level0 row2" >insured_education_level</th>
#       <td id="T_661f0_row2_col0" class="data row2 col0" >1000</td>
#       <td id="T_661f0_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_661f0_row2_col2" class="data row2 col2" >JD</td>
#       <td id="T_661f0_row2_col3" class="data row2 col3" >161</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row3" class="row_heading level0 row3" >insured_occupation</th>
#       <td id="T_661f0_row3_col0" class="data row3 col0" >1000</td>
#       <td id="T_661f0_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_661f0_row3_col2" class="data row3 col2" >machine-op-inspct</td>
#       <td id="T_661f0_row3_col3" class="data row3 col3" >93</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row4" class="row_heading level0 row4" >insured_hobbies</th>
#       <td id="T_661f0_row4_col0" class="data row4 col0" >1000</td>
#       <td id="T_661f0_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_661f0_row4_col2" class="data row4 col2" >reading</td>
#       <td id="T_661f0_row4_col3" class="data row4 col3" >64</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row5" class="row_heading level0 row5" >insured_relationship</th>
#       <td id="T_661f0_row5_col0" class="data row5 col0" >1000</td>
#       <td id="T_661f0_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_661f0_row5_col2" class="data row5 col2" >own-child</td>
#       <td id="T_661f0_row5_col3" class="data row5 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row6" class="row_heading level0 row6" >incident_type</th>
#       <td id="T_661f0_row6_col0" class="data row6 col0" >1000</td>
#       <td id="T_661f0_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_661f0_row6_col2" class="data row6 col2" >Multi-vehicle Collision</td>
#       <td id="T_661f0_row6_col3" class="data row6 col3" >419</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row7" class="row_heading level0 row7" >collision_type</th>
#       <td id="T_661f0_row7_col0" class="data row7 col0" >1000</td>
#       <td id="T_661f0_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_661f0_row7_col2" class="data row7 col2" >Rear Collision</td>
#       <td id="T_661f0_row7_col3" class="data row7 col3" >470</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row8" class="row_heading level0 row8" >incident_severity</th>
#       <td id="T_661f0_row8_col0" class="data row8 col0" >1000</td>
#       <td id="T_661f0_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_661f0_row8_col2" class="data row8 col2" >Minor Damage</td>
#       <td id="T_661f0_row8_col3" class="data row8 col3" >354</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row9" class="row_heading level0 row9" >authorities_contacted</th>
#       <td id="T_661f0_row9_col0" class="data row9 col0" >909</td>
#       <td id="T_661f0_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_661f0_row9_col2" class="data row9 col2" >Police</td>
#       <td id="T_661f0_row9_col3" class="data row9 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row10" class="row_heading level0 row10" >incident_state</th>
#       <td id="T_661f0_row10_col0" class="data row10 col0" >1000</td>
#       <td id="T_661f0_row10_col1" class="data row10 col1" >7</td>
#       <td id="T_661f0_row10_col2" class="data row10 col2" >NY</td>
#       <td id="T_661f0_row10_col3" class="data row10 col3" >262</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row11" class="row_heading level0 row11" >incident_city</th>
#       <td id="T_661f0_row11_col0" class="data row11 col0" >1000</td>
#       <td id="T_661f0_row11_col1" class="data row11 col1" >7</td>
#       <td id="T_661f0_row11_col2" class="data row11 col2" >Springfield</td>
#       <td id="T_661f0_row11_col3" class="data row11 col3" >157</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row12" class="row_heading level0 row12" >property_damage</th>
#       <td id="T_661f0_row12_col0" class="data row12 col0" >1000</td>
#       <td id="T_661f0_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_661f0_row12_col2" class="data row12 col2" >NO</td>
#       <td id="T_661f0_row12_col3" class="data row12 col3" >698</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row13" class="row_heading level0 row13" >police_report_available</th>
#       <td id="T_661f0_row13_col0" class="data row13 col0" >1000</td>
#       <td id="T_661f0_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_661f0_row13_col2" class="data row13 col2" >NO</td>
#       <td id="T_661f0_row13_col3" class="data row13 col3" >686</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row14" class="row_heading level0 row14" >auto_make</th>
#       <td id="T_661f0_row14_col0" class="data row14 col0" >1000</td>
#       <td id="T_661f0_row14_col1" class="data row14 col1" >14</td>
#       <td id="T_661f0_row14_col2" class="data row14 col2" >Saab</td>
#       <td id="T_661f0_row14_col3" class="data row14 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row15" class="row_heading level0 row15" >auto_model</th>
#       <td id="T_661f0_row15_col0" class="data row15 col0" >1000</td>
#       <td id="T_661f0_row15_col1" class="data row15 col1" >39</td>
#       <td id="T_661f0_row15_col2" class="data row15 col2" >RAM</td>
#       <td id="T_661f0_row15_col3" class="data row15 col3" >43</td>
#     </tr>
#     <tr>
#       <th id="T_661f0_level0_row16" class="row_heading level0 row16" >fraud_reported</th>
#       <td id="T_661f0_row16_col0" class="data row16 col0" >1000</td>
#       <td id="T_661f0_row16_col1" class="data row16 col1" >2</td>
#       <td id="T_661f0_row16_col2" class="data row16 col2" >N</td>
#       <td id="T_661f0_row16_col3" class="data row16 col3" >753</td>
#     </tr>
#   </tbody>
# </table>

# %%
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("="*100)
# Out:
# policy_state
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
# ====================================================================================================
# insured_sex
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
# ====================================================================================================
# insured_education_level
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
# ====================================================================================================
# insured_occupation
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# ====================================================================================================
# insured_hobbies
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
# ====================================================================================================
# insured_relationship
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
# ====================================================================================================
# incident_type
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
# ====================================================================================================
# collision_type
# collision_type
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: count, dtype: int64
# ====================================================================================================
# incident_severity
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
# ====================================================================================================
# authorities_contacted
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# Name: count, dtype: int64
# ====================================================================================================
# incident_state
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
# ====================================================================================================
# incident_city
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
# ====================================================================================================
# property_damage
# property_damage
# NO     698
# YES    302
# Name: count, dtype: int64
# ====================================================================================================
# police_report_available
# police_report_available
# NO     686
# YES    314
# Name: count, dtype: int64
# ====================================================================================================
# auto_make
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
# ====================================================================================================
# auto_model
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
# ====================================================================================================
# fraud_reported
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
# ====================================================================================================

# %%
print('Minimum Age :',df.age.min(),'Years')
print('Maximum Age :',df.age.max(),'Years')
print('Average Age :',df.age.mean(),'Years')
# Out:
# Minimum Age : 19 Years
# Maximum Age : 64 Years
# Average Age : 38.948 Years

# %%
df['age_bins'] = pd.cut(df.age, bins = [0, 10, 20, 30, 40, 50, 60, 70], 
                          include_lowest = True, labels = ['0-10','11-20','21-30','31-40', '41-50', '51-60', '61-70'])

# %%
pd.crosstab(df['incident_type'], df['incident_severity']).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_0fcef_row0_col0, #T_0fcef_row0_col2, #T_0fcef_row2_col1, #T_0fcef_row3_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_0fcef_row0_col1 {
#   background-color: #108866;
#   color: #f1f1f1;
# }
# #T_0fcef_row0_col3, #T_0fcef_row1_col0, #T_0fcef_row1_col1, #T_0fcef_row1_col2, #T_0fcef_row2_col3, #T_0fcef_row3_col0, #T_0fcef_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_0fcef_row1_col3 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_0fcef_row2_col0 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_0fcef_row2_col2 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_0fcef_row3_col1 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# </style>
# <table id="T_0fcef">
#   <thead>
#     <tr>
#       <th class="index_name level0" >incident_severity</th>
#       <th id="T_0fcef_level0_col0" class="col_heading level0 col0" >Major Damage</th>
#       <th id="T_0fcef_level0_col1" class="col_heading level0 col1" >Minor Damage</th>
#       <th id="T_0fcef_level0_col2" class="col_heading level0 col2" >Total Loss</th>
#       <th id="T_0fcef_level0_col3" class="col_heading level0 col3" >Trivial Damage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >incident_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fcef_level0_row0" class="row_heading level0 row0" >Multi-vehicle Collision</th>
#       <td id="T_0fcef_row0_col0" class="data row0 col0" >144</td>
#       <td id="T_0fcef_row0_col1" class="data row0 col1" >130</td>
#       <td id="T_0fcef_row0_col2" class="data row0 col2" >145</td>
#       <td id="T_0fcef_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0fcef_level0_row1" class="row_heading level0 row1" >Parked Car</th>
#       <td id="T_0fcef_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_0fcef_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_0fcef_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0fcef_row1_col3" class="data row1 col3" >42</td>
#     </tr>
#     <tr>
#       <th id="T_0fcef_level0_row2" class="row_heading level0 row2" >Single Vehicle Collision</th>
#       <td id="T_0fcef_row2_col0" class="data row2 col0" >132</td>
#       <td id="T_0fcef_row2_col1" class="data row2 col1" >136</td>
#       <td id="T_0fcef_row2_col2" class="data row2 col2" >135</td>
#       <td id="T_0fcef_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0fcef_level0_row3" class="row_heading level0 row3" >Vehicle Theft</th>
#       <td id="T_0fcef_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_0fcef_row3_col1" class="data row3 col1" >46</td>
#       <td id="T_0fcef_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0fcef_row3_col3" class="data row3 col3" >48</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
#    months_as_customer  age policy_state  policy_deductable  \
# 0                 328   48           OH               1000
# 1                 228   42           IN               2000
# 2                 134   29           OH               2000
# 3                 256   41           IL               2000
# 4                 228   44           IL               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_hobbies insured_relationship  capital-gains  \
# 0       craft-repair        sleeping              husband          53300
# 1  machine-op-inspct         reading       other-relative              0
# 2              sales     board-games            own-child          35100
# 3       armed-forces     board-games            unmarried          48900
# 4              sales     board-games            unmarried          66000
#
#    capital-loss             incident_type   collision_type incident_severity  \
# 0             0  Single Vehicle Collision   Side Collision      Major Damage
# 1             0             Vehicle Theft   Rear Collision      Minor Damage
# 2             0   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3        -62400  Single Vehicle Collision  Front Collision      Major Damage
# 4        -46000             Vehicle Theft   Rear Collision      Minor Damage
#
#   authorities_contacted incident_state incident_city  \
# 0                Police             SC      Columbus
# 1                Police             VA     Riverwood
# 2                Police             NY      Columbus
# 3                Police             OH     Arlington
# 4                   NaN             NY     Arlington
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1              NO
# 2                         7                            3              NO
# 3                         5                            1              NO
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                      NO                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#   fraud_reported CSL_Personal CSL_Accidental  policy_bind_day  \
# 0              Y          250            500               17
# 1              Y          250            500               27
# 2              N          100            300                6
# 3              Y          250            500               25
# 4              N          500           1000                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  9              2000            22               2
# 3                  5              1990            10               1
# 4                  6              2014            17               2
#
#    Automobile_Age age_bins
# 0              11    41-50
# 1               8    41-50
# 2               8    21-30
# 3               1    41-50
# 4               6    41-50

# %%
Category = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation',
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 
            'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               2                  0                      3               4
# 1               1                  1                      3               5
# 2               1                  1                      3               1
# 3               0                  0                      3               2
# 4               1                  1                      4               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                1                1          2                        1
# 1                0                0          0                        0
# 2                0                2          3                        0
# 3                0                1          2                        0
# 4                0                0          1                        0
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                6
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  9              2000            22               2
# 3                  5              1990            10               1
# 4                  6              2014            17               2
#
#    Automobile_Age age_bins
# 0              11    41-50
# 1               8    41-50
# 2               8    21-30
# 3               1    41-50
# 4               6    41-50

# %%
#Outliers detection and removal

# %%
Numerical = ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss',
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 
             'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age','policy_annual_premium']

# %%
plt.figure(figsize=(20,30),facecolor='red')
plotnumber=1

for column in Numerical:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#confirmed that the ouliers are present in the data

# %%
#Now we remove ouliers by Zscore method

# %%
df
# Out:
#      months_as_customer  age  policy_state  policy_deductable  \
# 0                   328   48             2               1000
# 1                   228   42             1               2000
# 2                   134   29             2               2000
# 3                   256   41             0               2000
# 4                   228   44             0               1000
# ..                  ...  ...           ...                ...
# 995                   3   38             2               1000
# 996                 285   41             0               1000
# 997                 130   34             2                500
# 998                 458   62             0               2000
# 999                 456   60             2               1000
#
#      policy_annual_premium  umbrella_limit  insured_sex  \
# 0                  1406.91               0            1
# 1                  1197.22         5000000            1
# 2                  1413.14         5000000            0
# 3                  1415.74         6000000            0
# 4                  1583.91         6000000            1
# ..                     ...             ...          ...
# 995                1310.80               0            0
# 996                1436.79               0            0
# 997                1383.49         3000000            0
# 998                1356.92         5000000            1
# 999                 766.19               0            0
#
#      insured_education_level  insured_occupation  insured_hobbies  \
# 0                          4                   2               17
# 1                          4                   6               15
# 2                          6                  11                2
# 3                          6                   1                2
# 4                          0                  11                2
# ..                       ...                 ...              ...
# 995                        5                   2               13
# 996                        6                   9               17
# 997                        5                   1                3
# 998                        0                   5                0
# 999                        0                  11               11
#
#      insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                       0          53300             0              2
# 1                       2              0             0              3
# 2                       3          35100             0              0
# 3                       4          48900        -62400              2
# 4                       4          66000        -46000              3
# ..                    ...            ...           ...            ...
# 995                     4              0             0              2
# 996                     5          70900             0              2
# 997                     2          35100             0              0
# 998                     5              0             0              2
# 999                     0              0             0              1
#
#      collision_type  incident_severity  authorities_contacted  incident_state  \
# 0                 2                  0                      3               4
# 1                 1                  1                      3               5
# 2                 1                  1                      3               1
# 3                 0                  0                      3               2
# 4                 1                  1                      4               1
# ..              ...                ...                    ...             ...
# 995               0                  1                      1               0
# 996               1                  0                      1               4
# 997               2                  1                      3               0
# 998               1                  0                      2               1
# 999               1                  1                      3               6
#
#      incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0                1                         5                            1
# 1                5                         8                            1
# 2                1                         7                            3
# 3                0                         5                            1
# 4                0                        20                            1
# ..             ...                       ...                          ...
# 995              4                        20                            1
# 996              3                        23                            1
# 997              0                         4                            3
# 998              0                         2                            1
# 999              1                         6                            1
#
#      property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                  1                1          2                        1
# 1                  0                0          0                        0
# 2                  0                2          3                        0
# 3                  0                1          2                        0
# 4                  0                0          1                        0
# ..               ...              ...        ...                      ...
# 995                1                0          1                        0
# 996                1                2          3                        0
# 997                0                2          3                        1
# 998                0                0          1                        1
# 999                0                0          3                        0
#
#      total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# 0                 71610          6510           13020          52080
# 1                  5070           780             780           3510
# 2                 34650          7700            3850          23100
# 3                 63400          6340            6340          50720
# 4                  6500          1300             650           4550
# ..                  ...           ...             ...            ...
# 995               87200         17440            8720          61040
# 996              108480         18080           18080          72320
# 997               67500          7500            7500          52500
# 998               46980          5220            5220          36540
# 999                5060           460             920           3680
#
#      auto_make  auto_model  fraud_reported  CSL_Personal  CSL_Accidental  \
# 0           10           1               1             1               2
# 1            8          12               1             1               2
# 2            4          30               0             0               1
# 3            3          34               1             1               2
# 4            0          31               0             2               0
# ..         ...         ...             ...           ...             ...
# 995          6           6               0             2               0
# 996         13          28               0             0               1
# 997         11          19               0             1               2
# 998          1           5               0             2               0
# 999          8          12               0             1               2
#
#      policy_bind_day  policy_bind_month  policy_bind_year  incident_day  \
# 0                 17                 10              2014            25
# 1                 27                  6              2006            21
# 2                  6                  9              2000            22
# 3                 25                  5              1990            10
# 4                  6                  6              2014            17
# ..               ...                ...               ...           ...
# 995               16                  7              1991            22
# 996                5                  1              2014            24
# 997               17                  2              2003            23
# 998               18                 11              2011            26
# 999               11                 11              1996            26
#
#      incident_month  Automobile_Age age_bins
# 0                 1              11    41-50
# 1                 1               8    41-50
# 2                 2               8    21-30
# 3                 1               1    41-50
# 4                 2               6    41-50
# ..              ...             ...      ...
# 995               2               9    31-40
# 996               1               0    41-50
# 997               1              19    31-40
# 998               2              17    61-70
# 999               2               8    51-60
#
# [1000 rows x 41 columns]

# %%
plt.figure(figsize=(20,30),facecolor='white')
sns.set_palette('plasma')
plotnum=1
for col in Numerical:
    if plotnum<=21:
        plt.subplot(7,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df[Numerical].skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_deductable              0.477887
# umbrella_limit                 1.806712
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# policy_bind_day                0.053237
# policy_bind_month             -0.016994
# policy_bind_year               0.052511
# incident_day                   0.039711
# incident_month                 0.267378
# Automobile_Age                 0.048289
# policy_annual_premium          0.004402
# dtype: float64

# %%
# Making the skew less than or equal to +0.5 and -0.5 for better prediction using yeo-johnson method
skew=['total_claim_amount','vehicle_claim']

# Importing Powertransformer
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
df[skew] = scaler.fit_transform(df[skew].values)

# %%
df[skew].skew()
# Out:
# total_claim_amount   -0.510354
# vehicle_claim        -0.522718
# dtype: float64

# %%
df.drop('age_bins',axis=1,inplace=True)

# %%
df
# Out:
#      months_as_customer  age  policy_state  policy_deductable  \
# 0                   328   48             2               1000
# 1                   228   42             1               2000
# 2                   134   29             2               2000
# 3                   256   41             0               2000
# 4                   228   44             0               1000
# ..                  ...  ...           ...                ...
# 995                   3   38             2               1000
# 996                 285   41             0               1000
# 997                 130   34             2                500
# 998                 458   62             0               2000
# 999                 456   60             2               1000
#
#      policy_annual_premium  umbrella_limit  insured_sex  \
# 0                  1406.91               0            1
# 1                  1197.22         5000000            1
# 2                  1413.14         5000000            0
# 3                  1415.74         6000000            0
# 4                  1583.91         6000000            1
# ..                     ...             ...          ...
# 995                1310.80               0            0
# 996                1436.79               0            0
# 997                1383.49         3000000            0
# 998                1356.92         5000000            1
# 999                 766.19               0            0
#
#      insured_education_level  insured_occupation  insured_hobbies  \
# 0                          4                   2               17
# 1                          4                   6               15
# 2                          6                  11                2
# 3                          6                   1                2
# 4                          0                  11                2
# ..                       ...                 ...              ...
# 995                        5                   2               13
# 996                        6                   9               17
# 997                        5                   1                3
# 998                        0                   5                0
# 999                        0                  11               11
#
#      insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                       0          53300             0              2
# 1                       2              0             0              3
# 2                       3          35100             0              0
# 3                       4          48900        -62400              2
# 4                       4          66000        -46000              3
# ..                    ...            ...           ...            ...
# 995                     4              0             0              2
# 996                     5          70900             0              2
# 997                     2          35100             0              0
# 998                     5              0             0              2
# 999                     0              0             0              1
#
#      collision_type  incident_severity  authorities_contacted  incident_state  \
# 0                 2                  0                      3               4
# 1                 1                  1                      3               5
# 2                 1                  1                      3               1
# 3                 0                  0                      3               2
# 4                 1                  1                      4               1
# ..              ...                ...                    ...             ...
# 995               0                  1                      1               0
# 996               1                  0                      1               4
# 997               2                  1                      3               0
# 998               1                  0                      2               1
# 999               1                  1                      3               6
#
#      incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0                1                         5                            1
# 1                5                         8                            1
# 2                1                         7                            3
# 3                0                         5                            1
# 4                0                        20                            1
# ..             ...                       ...                          ...
# 995              4                        20                            1
# 996              3                        23                            1
# 997              0                         4                            3
# 998              0                         2                            1
# 999              1                         6                            1
#
#      property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                  1                1          2                        1
# 1                  0                0          0                        0
# 2                  0                2          3                        0
# 3                  0                1          2                        0
# 4                  0                0          1                        0
# ..               ...              ...        ...                      ...
# 995                1                0          1                        0
# 996                1                2          3                        0
# 997                0                2          3                        1
# 998                0                0          1                        1
# 999                0                0          3                        0
#
#      total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# 0              0.715714          6510           13020       0.753697
# 1             -1.776979           780             780      -1.786629
# 2             -0.716825          7700            3850      -0.820881
# 3              0.391426          6340            6340       0.677602
# 4             -1.729802          1300             650      -1.740038
# ..                  ...           ...             ...            ...
# 995            1.338829         17440            8720       1.259186
# 996            2.202447         18080           18080       1.904757
# 997            0.553012          7500            7500       0.777232
# 998           -0.247520          5220            5220      -0.104258
# 999           -1.777306           460             920      -1.779087
#
#      auto_make  auto_model  fraud_reported  CSL_Personal  CSL_Accidental  \
# 0           10           1               1             1               2
# 1            8          12               1             1               2
# 2            4          30               0             0               1
# 3            3          34               1             1               2
# 4            0          31               0             2               0
# ..         ...         ...             ...           ...             ...
# 995          6           6               0             2               0
# 996         13          28               0             0               1
# 997         11          19               0             1               2
# 998          1           5               0             2               0
# 999          8          12               0             1               2
#
#      policy_bind_day  policy_bind_month  policy_bind_year  incident_day  \
# 0                 17                 10              2014            25
# 1                 27                  6              2006            21
# 2                  6                  9              2000            22
# 3                 25                  5              1990            10
# 4                  6                  6              2014            17
# ..               ...                ...               ...           ...
# 995               16                  7              1991            22
# 996                5                  1              2014            24
# 997               17                  2              2003            23
# 998               18                 11              2011            26
# 999               11                 11              1996            26
#
#      incident_month  Automobile_Age
# 0                 1              11
# 1                 1               8
# 2                 2               8
# 3                 1               1
# 4                 2               6
# ..              ...             ...
# 995               2               9
# 996               1               0
# 997               1              19
# 998               2              17
# 999               2               8
#
# [1000 rows x 40 columns]

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922098     -0.000328
# age                                    0.922098  1.000000     -0.014533
# policy_state                          -0.000328 -0.014533      1.000000
# policy_deductable                      0.026807  0.029188      0.010033
# policy_annual_premium                  0.005018  0.014404      0.012455
# umbrella_limit                         0.015498  0.018126     -0.029580
# insured_sex                            0.060925  0.073337     -0.020481
# insured_education_level               -0.000833  0.000969     -0.034327
# insured_occupation                     0.009814  0.017220     -0.031215
# insured_hobbies                       -0.093661 -0.081315     -0.038689
# insured_relationship                   0.069727  0.074832     -0.018506
# capital-gains                          0.006399 -0.007075      0.074551
# capital-loss                           0.020209  0.007368     -0.030338
# incident_type                         -0.017377 -0.025626      0.031848
# collision_type                        -0.072787 -0.075642      0.052438
# incident_severity                     -0.059581 -0.058439     -0.026377
# authorities_contacted                 -0.005007 -0.002761     -0.003782
# incident_state                         0.005369  0.005770      0.008723
# incident_city                         -0.000130 -0.002291     -0.002077
# incident_hour_of_the_day               0.070639  0.087161      0.029457
# number_of_vehicles_involved            0.014736  0.022102     -0.042263
# property_damage                        0.005488 -0.003408     -0.008465
# bodily_injuries                       -0.010162 -0.015679      0.013384
# witnesses                              0.058383  0.052359      0.022960
# police_report_available               -0.022146 -0.020441      0.069017
# total_claim_amount                     0.062495  0.070386     -0.006305
# injury_claim                           0.065329  0.075522     -0.046290
# property_claim                         0.034940  0.060898      0.008406
# vehicle_claim                          0.061308  0.062764      0.001464
# auto_make                              0.047655  0.030410      0.017124
# auto_model                             0.004202  0.017343     -0.025253
# fraud_reported                         0.020544  0.012143      0.029432
# CSL_Personal                          -0.026819 -0.015185      0.001027
# CSL_Accidental                         0.008876  0.009876      0.028838
# policy_bind_day                        0.054809  0.056776      0.011178
# policy_bind_month                     -0.001559  0.008357      0.046871
# policy_bind_year                      -0.048276 -0.037444     -0.007276
# incident_day                          -0.001455  0.003697      0.025572
# incident_month                        -0.042826 -0.037058      0.018531
# Automobile_Age                         0.000292 -0.001354     -0.002114
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.026807               0.005018
# age                                   0.029188               0.014404
# policy_state                          0.010033               0.012455
# policy_deductable                     1.000000              -0.003245
# policy_annual_premium                -0.003245               1.000000
# umbrella_limit                        0.010870              -0.006247
# insured_sex                          -0.009733               0.038853
# insured_education_level               0.015217              -0.019715
# insured_occupation                   -0.046733               0.035922
# insured_hobbies                       0.004061              -0.018019
# insured_relationship                 -0.022945               0.001925
# capital-gains                         0.035212              -0.013738
# capital-loss                         -0.023544               0.023547
# incident_type                        -0.038411               0.053603
# collision_type                       -0.053912               0.036556
# incident_severity                    -0.015711              -0.011155
# authorities_contacted                 0.011705              -0.046963
# incident_state                        0.006517               0.046434
# incident_city                        -0.045117               0.048724
# incident_hour_of_the_day              0.060935              -0.001578
# number_of_vehicles_involved           0.051214              -0.045991
# property_damage                       0.015770               0.080738
# bodily_injuries                      -0.022765               0.026780
# witnesses                             0.066639               0.002332
# police_report_available               0.038036               0.021998
# total_claim_amount                    0.023350               0.008400
# injury_claim                          0.039107              -0.017633
# property_claim                        0.064792              -0.011654
# vehicle_claim                         0.004875               0.020028
# auto_make                            -0.035379               0.000045
# auto_model                           -0.003268              -0.031849
# fraud_reported                        0.014817              -0.014480
# CSL_Personal                          0.003384               0.023978
# CSL_Accidental                       -0.003931               0.003813
# policy_bind_day                      -0.000265              -0.037933
# policy_bind_month                    -0.025020              -0.002480
# policy_bind_year                     -0.049598               0.001249
# incident_day                         -0.022701               0.028797
# incident_month                       -0.026416              -0.046097
# Automobile_Age                       -0.026105               0.049226
#
#                              umbrella_limit  insured_sex  \
# months_as_customer                 0.015498     0.060925
# age                                0.018126     0.073337
# policy_state                      -0.029580    -0.020481
# policy_deductable                  0.010870    -0.009733
# policy_annual_premium             -0.006247     0.038853
# umbrella_limit                     1.000000     0.010688
# insured_sex                        0.010688     1.000000
# insured_education_level           -0.019357     0.009002
# insured_occupation                 0.023422    -0.006160
# insured_hobbies                   -0.037000    -0.020317
# insured_relationship               0.077495     0.002855
# capital-gains                     -0.047268    -0.020494
# capital-loss                      -0.024056    -0.021705
# incident_type                      0.015966     0.009952
# collision_type                     0.010041    -0.014293
# incident_severity                  0.009466    -0.028168
# authorities_contacted              0.030998     0.030169
# incident_state                    -0.077492    -0.022379
# incident_city                      0.013094     0.014470
# incident_hour_of_the_day          -0.023257     0.019290
# number_of_vehicles_involved       -0.021270     0.018793
# property_damage                   -0.076358     0.026969
# bodily_injuries                    0.022743    -0.020297
# witnesses                         -0.006738     0.042463
# police_report_available           -0.044771     0.006992
# total_claim_amount                -0.040182    -0.024532
# injury_claim                      -0.045412     0.000924
# property_claim                    -0.023790    -0.014868
# vehicle_claim                     -0.038275    -0.030626
# auto_make                         -0.004443     0.026457
# auto_model                         0.040256    -0.018421
# fraud_reported                     0.058622     0.030873
# CSL_Personal                       0.021636    -0.010757
# CSL_Accidental                     0.015602     0.070700
# policy_bind_day                   -0.023361     0.039769
# policy_bind_month                 -0.045871    -0.001042
# policy_bind_year                   0.048008    -0.032891
# incident_day                      -0.009974     0.001924
# incident_month                    -0.002576    -0.025471
# Automobile_Age                    -0.009893     0.028247
#
#                              insured_education_level  insured_occupation  \
# months_as_customer                         -0.000833            0.009814
# age                                         0.000969            0.017220
# policy_state                               -0.034327           -0.031215
# policy_deductable                           0.015217           -0.046733
# policy_annual_premium                      -0.019715            0.035922
# umbrella_limit                             -0.019357            0.023422
# insured_sex                                 0.009002           -0.006160
# insured_education_level                     1.000000           -0.020298
# insured_occupation                         -0.020298            1.000000
# insured_hobbies                             0.021807           -0.011077
# insured_relationship                       -0.023488           -0.010171
# capital-gains                               0.039912           -0.007824
# capital-loss                                0.041193           -0.020171
# incident_type                               0.013704            0.003842
# collision_type                             -0.019230            0.007401
# incident_severity                          -0.006420            0.004731
# authorities_contacted                      -0.018744           -0.026398
# incident_state                             -0.005903           -0.022761
# incident_city                              -0.018636            0.000390
# incident_hour_of_the_day                   -0.057061           -0.018435
# number_of_vehicles_involved                -0.003768           -0.015368
# property_damage                            -0.048909           -0.016378
# bodily_injuries                            -0.012072           -0.000236
# witnesses                                   0.019211           -0.014794
# police_report_available                     0.051640           -0.025232
# total_claim_amount                          0.074466            0.003703
# injury_claim                                0.081880            0.020211
# property_claim                              0.055794            0.003004
# vehicle_claim                               0.068308           -0.000852
# auto_make                                   0.055202            0.042621
# auto_model                                  0.049445            0.020584
# fraud_reported                              0.008808            0.001564
# CSL_Personal                                0.009153            0.015788
# CSL_Accidental                             -0.006546           -0.003804
# policy_bind_day                             0.042708            0.007930
# policy_bind_month                          -0.082494           -0.010890
# policy_bind_year                            0.018952           -0.027085
# incident_day                               -0.038402           -0.018720
# incident_month                             -0.053106           -0.009459
# Automobile_Age                             -0.043509            0.006676
#
#                              insured_hobbies  insured_relationship  \
# months_as_customer                 -0.093661              0.069727
# age                                -0.081315              0.074832
# policy_state                       -0.038689             -0.018506
# policy_deductable                   0.004061             -0.022945
# policy_annual_premium              -0.018019              0.001925
# umbrella_limit                     -0.037000              0.077495
# insured_sex                        -0.020317              0.002855
# insured_education_level             0.021807             -0.023488
# insured_occupation                 -0.011077             -0.010171
# insured_hobbies                     1.000000             -0.096772
# insured_relationship               -0.096772              1.000000
# capital-gains                       0.054338             -0.019439
# capital-loss                       -0.031811             -0.064453
# incident_type                       0.007711              0.033834
# collision_type                      0.016700             -0.005850
# incident_severity                  -0.024688              0.015498
# authorities_contacted              -0.013333              0.012841
# incident_state                      0.085764             -0.062331
# incident_city                       0.018542             -0.002288
# incident_hour_of_the_day            0.019979              0.004805
# number_of_vehicles_involved         0.012586             -0.047354
# property_damage                     0.036193             -0.031931
# bodily_injuries                     0.031373             -0.001214
# witnesses                          -0.033971              0.002362
# police_report_available            -0.027937             -0.017471
# total_claim_amount                 -0.002978              0.003005
# injury_claim                        0.028393              0.029014
# property_claim                      0.012535              0.007332
# vehicle_claim                      -0.015568             -0.005663
# auto_make                           0.001525             -0.027028
# auto_model                          0.030948              0.063671
# fraud_reported                     -0.046838              0.021043
# CSL_Personal                       -0.005960             -0.030063
# CSL_Accidental                      0.036946             -0.043769
# policy_bind_day                     0.018657              0.018161
# policy_bind_month                   0.021391              0.019474
# policy_bind_year                   -0.013986             -0.006494
# incident_day                        0.019688             -0.080207
# incident_month                     -0.029502              0.005303
# Automobile_Age                      0.014495              0.023345
#
#                              capital-gains  capital-loss  incident_type  \
# months_as_customer                0.006399      0.020209      -0.017377
# age                              -0.007075      0.007368      -0.025626
# policy_state                      0.074551     -0.030338       0.031848
# policy_deductable                 0.035212     -0.023544      -0.038411
# policy_annual_premium            -0.013738      0.023547       0.053603
# umbrella_limit                   -0.047268     -0.024056       0.015966
# insured_sex                      -0.020494     -0.021705       0.009952
# insured_education_level           0.039912      0.041193       0.013704
# insured_occupation               -0.007824     -0.020171       0.003842
# insured_hobbies                   0.054338     -0.031811       0.007711
# insured_relationship             -0.019439     -0.064453       0.033834
# capital-gains                     1.000000     -0.046904      -0.045857
# capital-loss                     -0.046904      1.000000       0.026101
# incident_type                    -0.045857      0.026101       1.000000
# collision_type                   -0.006170      0.041494      -0.070920
# incident_severity                -0.013396     -0.018647       0.159915
# authorities_contacted            -0.021440      0.034518       0.209480
# incident_state                    0.013833     -0.048651       0.037083
# incident_city                    -0.024989     -0.038092       0.022117
# incident_hour_of_the_day         -0.016406     -0.025054      -0.133387
# number_of_vehicles_involved       0.061643     -0.014895      -0.893274
# property_damage                  -0.000616      0.016981       0.020263
# bodily_injuries                   0.055829     -0.024418      -0.009733
# witnesses                        -0.017651     -0.041330      -0.007299
# police_report_available          -0.012939     -0.039256       0.019917
# total_claim_amount                0.015210     -0.036694      -0.270055
# injury_claim                      0.025934     -0.046060      -0.226704
# property_claim                   -0.000779     -0.022863      -0.221409
# vehicle_claim                     0.014891     -0.033303      -0.263485
# auto_make                         0.052014     -0.041658      -0.032784
# auto_model                        0.036569     -0.037288      -0.034302
# fraud_reported                   -0.019173     -0.014863      -0.050376
# CSL_Personal                      0.005249     -0.034612       0.011997
# CSL_Accidental                    0.001635      0.008063      -0.006631
# policy_bind_day                  -0.004664     -0.025983      -0.000847
# policy_bind_month                 0.021193     -0.028124       0.014771
# policy_bind_year                  0.041249     -0.026420      -0.049407
# incident_day                      0.031922     -0.009696       0.006283
# incident_month                   -0.037097      0.005949      -0.087155
# Automobile_Age                   -0.031398      0.056615       0.053191
#
#                              collision_type  incident_severity  \
# months_as_customer                -0.072787          -0.059581
# age                               -0.075642          -0.058439
# policy_state                       0.052438          -0.026377
# policy_deductable                 -0.053912          -0.015711
# policy_annual_premium              0.036556          -0.011155
# umbrella_limit                     0.010041           0.009466
# insured_sex                       -0.014293          -0.028168
# insured_education_level           -0.019230          -0.006420
# insured_occupation                 0.007401           0.004731
# insured_hobbies                    0.016700          -0.024688
# insured_relationship              -0.005850           0.015498
# capital-gains                     -0.006170          -0.013396
# capital-loss                       0.041494          -0.018647
# incident_type                     -0.070920           0.159915
# collision_type                     1.000000          -0.014702
# incident_severity                 -0.014702           1.000000
# authorities_contacted              0.044065           0.276546
# incident_state                     0.031680           0.060019
# incident_city                      0.032114          -0.016541
# incident_hour_of_the_day           0.044074          -0.071946
# number_of_vehicles_involved        0.078999          -0.168719
# property_damage                    0.004059          -0.036102
# bodily_injuries                   -0.018146          -0.018870
# witnesses                         -0.046659          -0.011127
# police_report_available            0.047648           0.002808
# total_claim_amount                -0.012729          -0.360100
# injury_claim                      -0.024996          -0.276980
# property_claim                    -0.003844          -0.301861
# vehicle_claim                     -0.010023          -0.355943
# auto_make                         -0.007501          -0.008571
# auto_model                         0.024323          -0.046442
# fraud_reported                    -0.017315          -0.405988
# CSL_Personal                       0.020641           0.022530
# CSL_Accidental                    -0.017275           0.003459
# policy_bind_day                   -0.001539          -0.055806
# policy_bind_month                  0.012847           0.004305
# policy_bind_year                   0.026098           0.004322
# incident_day                       0.046319           0.016452
# incident_month                     0.010733           0.038110
# Automobile_Age                     0.001204           0.019646
#
#                              authorities_contacted  incident_state  \
# months_as_customer                       -0.005007        0.005369
# age                                      -0.002761        0.005770
# policy_state                             -0.003782        0.008723
# policy_deductable                         0.011705        0.006517
# policy_annual_premium                    -0.046963        0.046434
# umbrella_limit                            0.030998       -0.077492
# insured_sex                               0.030169       -0.022379
# insured_education_level                  -0.018744       -0.005903
# insured_occupation                       -0.026398       -0.022761
# insured_hobbies                          -0.013333        0.085764
# insured_relationship                      0.012841       -0.062331
# capital-gains                            -0.021440        0.013833
# capital-loss                              0.034518       -0.048651
# incident_type                             0.209480        0.037083
# collision_type                            0.044065        0.031680
# incident_severity                         0.276546        0.060019
# authorities_contacted                     1.000000        0.040230
# incident_state                            0.040230        1.000000
# incident_city                            -0.023593        0.014588
# incident_hour_of_the_day                 -0.156319       -0.036525
# number_of_vehicles_involved              -0.218862       -0.037384
# property_damage                          -0.010905       -0.045569
# bodily_injuries                           0.016057       -0.000036
# witnesses                                 0.004682        0.012177
# police_report_available                   0.034078        0.045007
# total_claim_amount                       -0.462909       -0.042156
# injury_claim                             -0.368887       -0.015826
# property_claim                           -0.356299       -0.026930
# vehicle_claim                            -0.462955       -0.048887
# auto_make                                -0.018380        0.070178
# auto_model                                0.033211       -0.039857
# fraud_reported                           -0.119702       -0.051407
# CSL_Personal                              0.085463        0.032814
# CSL_Accidental                           -0.005628        0.004413
# policy_bind_day                          -0.032152        0.043098
# policy_bind_month                        -0.037953       -0.013436
# policy_bind_year                         -0.035719       -0.025369
# incident_day                             -0.001954        0.011952
# incident_month                            0.020770       -0.013327
# Automobile_Age                           -0.054301        0.014658
#
#                              incident_city  incident_hour_of_the_day  \
# months_as_customer               -0.000130                  0.070639
# age                              -0.002291                  0.087161
# policy_state                     -0.002077                  0.029457
# policy_deductable                -0.045117                  0.060935
# policy_annual_premium             0.048724                 -0.001578
# umbrella_limit                    0.013094                 -0.023257
# insured_sex                       0.014470                  0.019290
# insured_education_level          -0.018636                 -0.057061
# insured_occupation                0.000390                 -0.018435
# insured_hobbies                   0.018542                  0.019979
# insured_relationship             -0.002288                  0.004805
# capital-gains                    -0.024989                 -0.016406
# capital-loss                     -0.038092                 -0.025054
# incident_type                     0.022117                 -0.133387
# collision_type                    0.032114                  0.044074
# incident_severity                -0.016541                 -0.071946
# authorities_contacted            -0.023593                 -0.156319
# incident_state                    0.014588                 -0.036525
# incident_city                     1.000000                  0.017039
# incident_hour_of_the_day          0.017039                  1.000000
# number_of_vehicles_involved      -0.009840                  0.120794
# property_damage                   0.009879                  0.064425
# bodily_injuries                   0.051782                 -0.034563
# witnesses                         0.009058                  0.006527
# police_report_available           0.010203                  0.040558
# total_claim_amount                0.042821                  0.214318
# injury_claim                      0.045794                  0.165768
# property_claim                    0.041101                  0.179536
# vehicle_claim                     0.037016                  0.211365
# auto_make                        -0.002237                 -0.002556
# auto_model                        0.015118                 -0.058342
# fraud_reported                   -0.040403                  0.004316
# CSL_Personal                      0.009333                 -0.001869
# CSL_Accidental                   -0.025689                  0.005211
# policy_bind_day                   0.033702                 -0.013954
# policy_bind_month                 0.031900                  0.010163
# policy_bind_year                 -0.010343                  0.035412
# incident_day                     -0.048857                 -0.016537
# incident_month                    0.011093                 -0.003416
# Automobile_Age                   -0.058645                 -0.021368
#
#                              number_of_vehicles_involved  property_damage  \
# months_as_customer                              0.014736         0.005488
# age                                             0.022102        -0.003408
# policy_state                                   -0.042263        -0.008465
# policy_deductable                               0.051214         0.015770
# policy_annual_premium                          -0.045991         0.080738
# umbrella_limit                                 -0.021270        -0.076358
# insured_sex                                     0.018793         0.026969
# insured_education_level                        -0.003768        -0.048909
# insured_occupation                             -0.015368        -0.016378
# insured_hobbies                                 0.012586         0.036193
# insured_relationship                           -0.047354        -0.031931
# capital-gains                                   0.061643        -0.000616
# capital-loss                                   -0.014895         0.016981
# incident_type                                  -0.893274         0.020263
# collision_type                                  0.078999         0.004059
# incident_severity                              -0.168719        -0.036102
# authorities_contacted                          -0.218862        -0.010905
# incident_state                                 -0.037384        -0.045569
# incident_city                                  -0.009840         0.009879
# incident_hour_of_the_day                        0.120794         0.064425
# number_of_vehicles_involved                     1.000000        -0.013641
# property_damage                                -0.013641         1.000000
# bodily_injuries                                 0.014030         0.003762
# witnesses                                      -0.014669        -0.019753
# police_report_available                        -0.007291        -0.022657
# total_claim_amount                              0.267331         0.061744
# injury_claim                                    0.224650         0.048886
# property_claim                                  0.219084         0.045211
# vehicle_claim                                   0.260793         0.062087
# auto_make                                       0.014343        -0.010203
# auto_model                                      0.032219        -0.051472
# fraud_reported                                  0.051839         0.017202
# CSL_Personal                                   -0.019403        -0.027634
# CSL_Accidental                                  0.005135         0.009732
# policy_bind_day                                -0.000655        -0.018134
# policy_bind_month                              -0.026949         0.022529
# policy_bind_year                                0.026595         0.017939
# incident_day                                   -0.013348         0.012945
# incident_month                                  0.052258         0.000866
# Automobile_Age                                 -0.034554         0.037711
#
#                              bodily_injuries  witnesses  \
# months_as_customer                 -0.010162   0.058383
# age                                -0.015679   0.052359
# policy_state                        0.013384   0.022960
# policy_deductable                  -0.022765   0.066639
# policy_annual_premium               0.026780   0.002332
# umbrella_limit                      0.022743  -0.006738
# insured_sex                        -0.020297   0.042463
# insured_education_level            -0.012072   0.019211
# insured_occupation                 -0.000236  -0.014794
# insured_hobbies                     0.031373  -0.033971
# insured_relationship               -0.001214   0.002362
# capital-gains                       0.055829  -0.017651
# capital-loss                       -0.024418  -0.041330
# incident_type                      -0.009733  -0.007299
# collision_type                     -0.018146  -0.046659
# incident_severity                  -0.018870  -0.011127
# authorities_contacted               0.016057   0.004682
# incident_state                     -0.000036   0.012177
# incident_city                       0.051782   0.009058
# incident_hour_of_the_day           -0.034563   0.006527
# number_of_vehicles_involved         0.014030  -0.014669
# property_damage                     0.003762  -0.019753
# bodily_injuries                     1.000000  -0.005606
# witnesses                          -0.005606   1.000000
# police_report_available             0.011860   0.048653
# total_claim_amount                  0.048629  -0.011124
# injury_claim                        0.047319  -0.024843
# property_claim                      0.039749   0.052640
# vehicle_claim                       0.045074  -0.023260
# auto_make                           0.026731   0.005603
# auto_model                          0.020007  -0.011232
# fraud_reported                      0.033877   0.049497
# CSL_Personal                       -0.000595   0.071500
# CSL_Accidental                     -0.016047  -0.012116
# policy_bind_day                    -0.045648  -0.008506
# policy_bind_month                  -0.025294   0.018727
# policy_bind_year                    0.029987   0.055907
# incident_day                       -0.020979   0.003785
# incident_month                      0.002256   0.012810
# Automobile_Age                      0.020527  -0.045791
#
#                              police_report_available  total_claim_amount  \
# months_as_customer                         -0.022146            0.062495
# age                                        -0.020441            0.070386
# policy_state                                0.069017           -0.006305
# policy_deductable                           0.038036            0.023350
# policy_annual_premium                       0.021998            0.008400
# umbrella_limit                             -0.044771           -0.040182
# insured_sex                                 0.006992           -0.024532
# insured_education_level                     0.051640            0.074466
# insured_occupation                         -0.025232            0.003703
# insured_hobbies                            -0.027937           -0.002978
# insured_relationship                       -0.017471            0.003005
# capital-gains                              -0.012939            0.015210
# capital-loss                               -0.039256           -0.036694
# incident_type                               0.019917           -0.270055
# collision_type                              0.047648           -0.012729
# incident_severity                           0.002808           -0.360100
# authorities_contacted                       0.034078           -0.462909
# incident_state                              0.045007           -0.042156
# incident_city                               0.010203            0.042821
# incident_hour_of_the_day                    0.040558            0.214318
# number_of_vehicles_involved                -0.007291            0.267331
# property_damage                            -0.022657            0.061744
# bodily_injuries                             0.011860            0.048629
# witnesses                                   0.048653           -0.011124
# police_report_available                     1.000000            0.035921
# total_claim_amount                          0.035921            1.000000
# injury_claim                                0.028211            0.806392
# property_claim                              0.012423            0.812322
# vehicle_claim                               0.040122            0.981220
# auto_make                                   0.068149           -0.058804
# auto_model                                 -0.017974            0.040885
# fraud_reported                             -0.027768            0.161867
# CSL_Personal                               -0.001645           -0.054800
# CSL_Accidental                              0.056154           -0.012461
# policy_bind_day                            -0.011423            0.014962
# policy_bind_month                          -0.029274            0.014045
# policy_bind_year                           -0.011907           -0.001780
# incident_day                                0.025251           -0.033370
# incident_month                              0.009286           -0.036381
# Automobile_Age                              0.022339            0.035796
#
#                              injury_claim  property_claim  vehicle_claim  \
# months_as_customer               0.065329        0.034940       0.061308
# age                              0.075522        0.060898       0.062764
# policy_state                    -0.046290        0.008406       0.001464
# policy_deductable                0.039107        0.064792       0.004875
# policy_annual_premium           -0.017633       -0.011654       0.020028
# umbrella_limit                  -0.045412       -0.023790      -0.038275
# insured_sex                      0.000924       -0.014868      -0.030626
# insured_education_level          0.081880        0.055794       0.068308
# insured_occupation               0.020211        0.003004      -0.000852
# insured_hobbies                  0.028393        0.012535      -0.015568
# insured_relationship             0.029014        0.007332      -0.005663
# capital-gains                    0.025934       -0.000779       0.014891
# capital-loss                    -0.046060       -0.022863      -0.033303
# incident_type                   -0.226704       -0.221409      -0.263485
# collision_type                  -0.024996       -0.003844      -0.010023
# incident_severity               -0.276980       -0.301861      -0.355943
# authorities_contacted           -0.368887       -0.356299      -0.462955
# incident_state                  -0.015826       -0.026930      -0.048887
# incident_city                    0.045794        0.041101       0.037016
# incident_hour_of_the_day         0.165768        0.179536       0.211365
# number_of_vehicles_involved      0.224650        0.219084       0.260793
# property_damage                  0.048886        0.045211       0.062087
# bodily_injuries                  0.047319        0.039749       0.045074
# witnesses                       -0.024843        0.052640      -0.023260
# police_report_available          0.028211        0.012423       0.040122
# total_claim_amount               0.806392        0.812322       0.981220
# injury_claim                     1.000000        0.563866       0.720711
# property_claim                   0.563866        1.000000       0.730292
# vehicle_claim                    0.720711        0.730292       1.000000
# auto_make                       -0.039575       -0.042030      -0.060922
# auto_model                       0.038136        0.048857       0.034628
# fraud_reported                   0.090975        0.137835       0.168249
# CSL_Personal                    -0.078818       -0.042216      -0.045278
# CSL_Accidental                   0.007745       -0.013888      -0.015989
# policy_bind_day                  0.024859        0.007739       0.012407
# policy_bind_month               -0.008774        0.023367       0.015949
# policy_bind_year                 0.002529       -0.000970      -0.002760
# incident_day                    -0.026634       -0.008379      -0.037854
# incident_month                  -0.020664       -0.077109      -0.025055
# Automobile_Age                   0.013718        0.014508       0.042947
#
#                              auto_make  auto_model  fraud_reported  \
# months_as_customer            0.047655    0.004202        0.020544
# age                           0.030410    0.017343        0.012143
# policy_state                  0.017124   -0.025253        0.029432
# policy_deductable            -0.035379   -0.003268        0.014817
# policy_annual_premium         0.000045   -0.031849       -0.014480
# umbrella_limit               -0.004443    0.040256        0.058622
# insured_sex                   0.026457   -0.018421        0.030873
# insured_education_level       0.055202    0.049445        0.008808
# insured_occupation            0.042621    0.020584        0.001564
# insured_hobbies               0.001525    0.030948       -0.046838
# insured_relationship         -0.027028    0.063671        0.021043
# capital-gains                 0.052014    0.036569       -0.019173
# capital-loss                 -0.041658   -0.037288       -0.014863
# incident_type                -0.032784   -0.034302       -0.050376
# collision_type               -0.007501    0.024323       -0.017315
# incident_severity            -0.008571   -0.046442       -0.405988
# authorities_contacted        -0.018380    0.033211       -0.119702
# incident_state                0.070178   -0.039857       -0.051407
# incident_city                -0.002237    0.015118       -0.040403
# incident_hour_of_the_day     -0.002556   -0.058342        0.004316
# number_of_vehicles_involved   0.014343    0.032219        0.051839
# property_damage              -0.010203   -0.051472        0.017202
# bodily_injuries               0.026731    0.020007        0.033877
# witnesses                     0.005603   -0.011232        0.049497
# police_report_available       0.068149   -0.017974       -0.027768
# total_claim_amount           -0.058804    0.040885        0.161867
# injury_claim                 -0.039575    0.038136        0.090975
# property_claim               -0.042030    0.048857        0.137835
# vehicle_claim                -0.060922    0.034628        0.168249
# auto_make                     1.000000   -0.166295       -0.027519
# auto_model                   -0.166295    1.000000        0.000720
# fraud_reported               -0.027519    0.000720        1.000000
# CSL_Personal                 -0.004701    0.047885       -0.037190
# CSL_Accidental               -0.032594   -0.007946        0.041475
# policy_bind_day              -0.026183    0.002128        0.063040
# policy_bind_month            -0.013696   -0.036670       -0.035180
# policy_bind_year             -0.004779    0.026988       -0.000059
# incident_day                  0.056957   -0.034317       -0.045955
# incident_month               -0.053444   -0.033938       -0.028847
# Automobile_Age               -0.004939   -0.032831       -0.007928
#
#                              CSL_Personal  CSL_Accidental  policy_bind_day  \
# months_as_customer              -0.026819        0.008876         0.054809
# age                             -0.015185        0.009876         0.056776
# policy_state                     0.001027        0.028838         0.011178
# policy_deductable                0.003384       -0.003931        -0.000265
# policy_annual_premium            0.023978        0.003813        -0.037933
# umbrella_limit                   0.021636        0.015602        -0.023361
# insured_sex                     -0.010757        0.070700         0.039769
# insured_education_level          0.009153       -0.006546         0.042708
# insured_occupation               0.015788       -0.003804         0.007930
# insured_hobbies                 -0.005960        0.036946         0.018657
# insured_relationship            -0.030063       -0.043769         0.018161
# capital-gains                    0.005249        0.001635        -0.004664
# capital-loss                    -0.034612        0.008063        -0.025983
# incident_type                    0.011997       -0.006631        -0.000847
# collision_type                   0.020641       -0.017275        -0.001539
# incident_severity                0.022530        0.003459        -0.055806
# authorities_contacted            0.085463       -0.005628        -0.032152
# incident_state                   0.032814        0.004413         0.043098
# incident_city                    0.009333       -0.025689         0.033702
# incident_hour_of_the_day        -0.001869        0.005211        -0.013954
# number_of_vehicles_involved     -0.019403        0.005135        -0.000655
# property_damage                 -0.027634        0.009732        -0.018134
# bodily_injuries                 -0.000595       -0.016047        -0.045648
# witnesses                        0.071500       -0.012116        -0.008506
# police_report_available         -0.001645        0.056154        -0.011423
# total_claim_amount              -0.054800       -0.012461         0.014962
# injury_claim                    -0.078818        0.007745         0.024859
# property_claim                  -0.042216       -0.013888         0.007739
# vehicle_claim                   -0.045278       -0.015989         0.012407
# auto_make                       -0.004701       -0.032594        -0.026183
# auto_model                       0.047885       -0.007946         0.002128
# fraud_reported                  -0.037190        0.041475         0.063040
# CSL_Personal                     1.000000       -0.459462         0.010164
# CSL_Accidental                  -0.459462        1.000000         0.011589
# policy_bind_day                  0.010164        0.011589         1.000000
# policy_bind_month               -0.021547        0.029286         0.030867
# policy_bind_year                -0.016466        0.002903         0.007943
# incident_day                    -0.007640        0.017088         0.008522
# incident_month                  -0.030164        0.018278         0.004512
# Automobile_Age                   0.033082       -0.033820        -0.036552
#
#                              policy_bind_month  policy_bind_year  \
# months_as_customer                   -0.001559         -0.048276
# age                                   0.008357         -0.037444
# policy_state                          0.046871         -0.007276
# policy_deductable                    -0.025020         -0.049598
# policy_annual_premium                -0.002480          0.001249
# umbrella_limit                       -0.045871          0.048008
# insured_sex                          -0.001042         -0.032891
# insured_education_level              -0.082494          0.018952
# insured_occupation                   -0.010890         -0.027085
# insured_hobbies                       0.021391         -0.013986
# insured_relationship                  0.019474         -0.006494
# capital-gains                         0.021193          0.041249
# capital-loss                         -0.028124         -0.026420
# incident_type                         0.014771         -0.049407
# collision_type                        0.012847          0.026098
# incident_severity                     0.004305          0.004322
# authorities_contacted                -0.037953         -0.035719
# incident_state                       -0.013436         -0.025369
# incident_city                         0.031900         -0.010343
# incident_hour_of_the_day              0.010163          0.035412
# number_of_vehicles_involved          -0.026949          0.026595
# property_damage                       0.022529          0.017939
# bodily_injuries                      -0.025294          0.029987
# witnesses                             0.018727          0.055907
# police_report_available              -0.029274         -0.011907
# total_claim_amount                    0.014045         -0.001780
# injury_claim                         -0.008774          0.002529
# property_claim                        0.023367         -0.000970
# vehicle_claim                         0.015949         -0.002760
# auto_make                            -0.013696         -0.004779
# auto_model                           -0.036670          0.026988
# fraud_reported                       -0.035180         -0.000059
# CSL_Personal                         -0.021547         -0.016466
# CSL_Accidental                        0.029286          0.002903
# policy_bind_day                       0.030867          0.007943
# policy_bind_month                     1.000000         -0.029324
# policy_bind_year                     -0.029324          1.000000
# incident_day                          0.002500          0.033643
# incident_month                        0.075224          0.045554
# Automobile_Age                        0.030265         -0.015164
#
#                              incident_day  incident_month  Automobile_Age
# months_as_customer              -0.001455       -0.042826        0.000292
# age                              0.003697       -0.037058       -0.001354
# policy_state                     0.025572        0.018531       -0.002114
# policy_deductable               -0.022701       -0.026416       -0.026105
# policy_annual_premium            0.028797       -0.046097        0.049226
# umbrella_limit                  -0.009974       -0.002576       -0.009893
# insured_sex                      0.001924       -0.025471        0.028247
# insured_education_level         -0.038402       -0.053106       -0.043509
# insured_occupation              -0.018720       -0.009459        0.006676
# insured_hobbies                  0.019688       -0.029502        0.014495
# insured_relationship            -0.080207        0.005303        0.023345
# capital-gains                    0.031922       -0.037097       -0.031398
# capital-loss                    -0.009696        0.005949        0.056615
# incident_type                    0.006283       -0.087155        0.053191
# collision_type                   0.046319        0.010733        0.001204
# incident_severity                0.016452        0.038110        0.019646
# authorities_contacted           -0.001954        0.020770       -0.054301
# incident_state                   0.011952       -0.013327        0.014658
# incident_city                   -0.048857        0.011093       -0.058645
# incident_hour_of_the_day        -0.016537       -0.003416       -0.021368
# number_of_vehicles_involved     -0.013348        0.052258       -0.034554
# property_damage                  0.012945        0.000866        0.037711
# bodily_injuries                 -0.020979        0.002256        0.020527
# witnesses                        0.003785        0.012810       -0.045791
# police_report_available          0.025251        0.009286        0.022339
# total_claim_amount              -0.033370       -0.036381        0.035796
# injury_claim                    -0.026634       -0.020664        0.013718
# property_claim                  -0.008379       -0.077109        0.014508
# vehicle_claim                   -0.037854       -0.025055        0.042947
# auto_make                        0.056957       -0.053444       -0.004939
# auto_model                      -0.034317       -0.033938       -0.032831
# fraud_reported                  -0.045955       -0.028847       -0.007928
# CSL_Personal                    -0.007640       -0.030164        0.033082
# CSL_Accidental                   0.017088        0.018278       -0.033820
# policy_bind_day                  0.008522        0.004512       -0.036552
# policy_bind_month                0.002500        0.075224        0.030265
# policy_bind_year                 0.033643        0.045554       -0.015164
# incident_day                     1.000000       -0.140093       -0.007475
# incident_month                  -0.140093        1.000000        0.018456
# Automobile_Age                  -0.007475        0.018456        1.000000

# %%
df.fraud_reported.value_counts()
# Out:
# fraud_reported
# 0    753
# 1    247
# Name: count, dtype: int64

# %%
#Now we will balance it

# %%
from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = df.drop(['fraud_reported'], axis =1)
Y = df['fraud_reported']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# fraud_reported
# 1    753
# 0    753
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
#checking for Vif values

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif
# Out:
#       VIF values                     Features
# 0       7.365792           months_as_customer
# 1       7.318749                          age
# 2       1.060324                 policy_state
# 3       1.058770            policy_deductable
# 4       1.055614        policy_annual_premium
# 5       1.046457               umbrella_limit
# 6       1.077943                  insured_sex
# 7       1.070948      insured_education_level
# 8       1.028185           insured_occupation
# 9       1.071333              insured_hobbies
# 10      1.075567         insured_relationship
# 11      1.070008                capital-gains
# 12      1.064415                 capital-loss
# 13      3.795497                incident_type
# 14      1.100599               collision_type
# 15      1.379783            incident_severity
# 16      1.460641        authorities_contacted
# 17      1.071267               incident_state
# 18      1.054786                incident_city
# 19      1.124478     incident_hour_of_the_day
# 20      3.613127  number_of_vehicles_involved
# 21      1.064025              property_damage
# 22      1.051416              bodily_injuries
# 23      1.057085                    witnesses
# 24      1.091903      police_report_available
# 25  44902.249964           total_claim_amount
# 26   1817.759170                 injury_claim
# 27   1749.575822               property_claim
# 28  22229.925960                vehicle_claim
# 29      1.084631                    auto_make
# 30      1.087651                   auto_model
# 31      1.252176                 CSL_Personal
# 32      1.224394               CSL_Accidental
# 33      1.035743              policy_bind_day
# 34      1.053049            policy_bind_month
# 35      1.039458             policy_bind_year
# 36      1.062468                 incident_day
# 37      1.109474               incident_month
# 38      1.057927               Automobile_Age

# %%
#PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=28)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(28))

# %%
#Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1054, 28)
# Training target vector size: (1054,)
# Test feature matrix size: (452, 28)
# Test target vector size: (452,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8141592920353983 on Random_state 71

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=9, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.7522123893805309
#
#
# Confusion matrix of Logistics Regression :
#  [[164  66]
#  [ 46 176]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.78      0.71      0.75       230
#            1       0.73      0.79      0.76       222
#
#     accuracy                           0.75       452
#    macro avg       0.75      0.75      0.75       452
# weighted avg       0.75      0.75      0.75       452

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.48197602114187404
# RMSE value for k=  2 is: 0.4412371986661207
# RMSE value for k=  3 is: 0.5065936913756358
# RMSE value for k=  4 is: 0.4955554673686267
# RMSE value for k=  5 is: 0.5131026566713389
# RMSE value for k=  6 is: 0.504405371463332
# RMSE value for k=  7 is: 0.5424461149373452
# RMSE value for k=  8 is: 0.5152540399295447
# RMSE value for k=  9 is: 0.5383521234745504
# RMSE value for k=  10 is: 0.525878952389589
# RMSE value for k=  11 is: 0.5444815671729857
# RMSE value for k=  12 is: 0.5383521234745504
# RMSE value for k=  13 is: 0.5604991454368136
# RMSE value for k=  14 is: 0.5444815671729857
# RMSE value for k=  15 is: 0.5604991454368136
# RMSE value for k=  16 is: 0.5485298130021853
# RMSE value for k=  17 is: 0.5741480799402843
# RMSE value for k=  18 is: 0.5565379710984114
# RMSE value for k=  19 is: 0.5722181649673349
# RMSE value for k=  20 is: 0.5585220699801103

# %%
#Applying other models

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('==========================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.7522123893805309
#
#
# Confusion matrix :
#  [[164  66]
#  [ 46 176]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.78      0.71      0.75       230
#            1       0.73      0.79      0.76       222
#
#     accuracy                           0.75       452
#    macro avg       0.75      0.75      0.75       452
# weighted avg       0.75      0.75      0.75       452
#
#
#
# ==========================================================================================
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.7986725663716814
#
#
# Confusion matrix :
#  [[184  46]
#  [ 45 177]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       230
#            1       0.79      0.80      0.80       222
#
#     accuracy                           0.80       452
#    macro avg       0.80      0.80      0.80       452
# weighted avg       0.80      0.80      0.80       452
#
#
#
# ==========================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.7853982300884956
#
#
# Confusion matrix :
#  [[183  47]
#  [ 50 172]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79       230
#            1       0.79      0.77      0.78       222
#
#     accuracy                           0.79       452
#    macro avg       0.79      0.79      0.79       452
# weighted avg       0.79      0.79      0.79       452
#
#
#
# ==========================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.7256637168141593
#
#
# Confusion matrix :
#  [[161  69]
#  [ 55 167]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72       230
#            1       0.71      0.75      0.73       222
#
#     accuracy                           0.73       452
#    macro avg       0.73      0.73      0.73       452
# weighted avg       0.73      0.73      0.73       452
#
#
#
# ==========================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=3) is
#
#
# Accuracy Score :
#  0.7433628318584071
#
#
# Confusion matrix :
#  [[124 106]
#  [ 10 212]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.93      0.54      0.68       230
#            1       0.67      0.95      0.79       222
#
#     accuracy                           0.74       452
#    macro avg       0.80      0.75      0.73       452
# weighted avg       0.80      0.74      0.73       452
#
#
#
# ==========================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8097345132743363
#
#
# Confusion matrix :
#  [[194  36]
#  [ 50 172]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       230
#            1       0.83      0.77      0.80       222
#
#     accuracy                           0.81       452
#    macro avg       0.81      0.81      0.81       452
# weighted avg       0.81      0.81      0.81       452
#
#
#
# ==========================================================================================
# Classification ML Algorithm Evaluation Matrix ExtraTreesClassifier() is
#
#
# Accuracy Score :
#  0.8252212389380531
#
#
# Confusion matrix :
#  [[194  36]
#  [ 43 179]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       230
#            1       0.83      0.81      0.82       222
#
#     accuracy                           0.83       452
#    macro avg       0.83      0.82      0.83       452
# weighted avg       0.83      0.83      0.83       452
#
#
#
# ==========================================================================================

# %%
#Cross Validation

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('===========================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.59933775 0.70431894 0.81063123 0.86046512 0.87375415]
# Mean Score : 0.7697014367120635
# Std deviation : 0.10396049131641878
#
#
# ===========================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.59271523 0.75415282 0.89036545 0.90033223 0.93023256]
# Mean Score : 0.8135596576532971
# Std deviation : 0.1259703188442728
#
#
# ===========================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.59271523 0.71096346 0.84053156 0.86046512 0.84385382]
# Mean Score : 0.7697058370552903
# Std deviation : 0.10346767152226444
#
#
# ===========================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.56953642 0.66112957 0.73089701 0.7641196  0.75747508]
# Mean Score : 0.6966315372599062
# Std deviation : 0.07327244522388784
#
#
# ===========================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.70529801 0.71760797 0.74418605 0.77740864 0.75747508]
# Mean Score : 0.7403951508217641
# Std deviation : 0.026180747578911194
#
#
# ===========================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.60264901 0.74750831 0.86378738 0.90697674 0.93355482]
# Mean Score : 0.8108952498294866
# Std deviation : 0.12203196507094419
#
#
# ===========================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.64900662 0.75747508 0.88704319 0.92358804 0.92358804]
# Mean Score : 0.8281401949352049
# Std deviation : 0.1084182085830888
#
#
# ===========================================================================

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
             'max_features':['auto','sqrt','log2'],
              'min_samples_split':[3,5,8,11],
              'max_depth' : [10,20,30],
              'n_estimators' : [100,200,300,400]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.834 total time=   0.1s
# [CV 2/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.844 total time=   0.1s
# [CV 3/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.796 total time=   0.1s
# [CV 4/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.735 total time=   0.1s
# [CV 5/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 5/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 1/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 1/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.815 total time=   0.3s
# [CV 2/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 2/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 3/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 3/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.796 total time=   0.3s
# [CV 4/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 4/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.763 total time=   0.3s
# [CV 5/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 5/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.852 total time=   0.3s
# [CV 1/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 1/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.825 total time=   0.8s
# [CV 2/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 2/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.815 total time=   0.6s
# [CV 3/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 3/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.815 total time=   0.5s
# [CV 4/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 4/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.768 total time=   0.5s
# [CV 5/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 5/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.852 total time=   0.5s
# [CV 1/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 1/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.829 total time=   0.7s
# [CV 2/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 2/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.820 total time=   0.7s
# [CV 3/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 3/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.806 total time=   0.8s
# [CV 4/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 4/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.758 total time=   0.6s
# [CV 5/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 5/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.848 total time=   0.6s
# [CV 1/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 1/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 2/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 2/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.834 total time=   0.1s
# [CV 3/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 3/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.806 total time=   0.1s
# [CV 4/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 4/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.763 total time=   0.1s
# [CV 5/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 5/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 1/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 1/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.820 total time=   0.3s
# [CV 2/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 2/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 3/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 3/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.810 total time=   0.4s
# [CV 4/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 4/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.791 total time=   0.3s
# [CV 5/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 5/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.843 total time=   0.4s
# [CV 1/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 1/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.839 total time=   0.6s
# [CV 2/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 2/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.810 total time=   0.6s
# [CV 3/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 3/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.815 total time=   0.5s
# [CV 4/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 4/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.768 total time=   0.5s
# [CV 5/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 5/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.862 total time=   0.4s
# [CV 1/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 1/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.825 total time=   0.6s
# [CV 2/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 2/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.829 total time=   0.7s
# [CV 3/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 3/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.815 total time=   0.6s
# [CV 4/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 4/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.754 total time=   0.6s
# [CV 5/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 5/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.848 total time=   0.7s
# [CV 1/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 1/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.848 total time=   0.2s
# [CV 2/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 2/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 3/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 3/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.806 total time=   0.2s
# [CV 4/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 4/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.768 total time=   0.2s
# [CV 5/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 5/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.824 total time=   0.2s
# [CV 1/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 1/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.834 total time=   0.3s
# [CV 2/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 2/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.801 total time=   0.4s
# [CV 3/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 3/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.801 total time=   0.3s
# [CV 4/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 4/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.768 total time=   0.2s
# [CV 5/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 5/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 1/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 1/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.825 total time=   0.5s
# [CV 2/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 2/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.815 total time=   0.4s
# [CV 3/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 3/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.791 total time=   0.5s
# [CV 4/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 4/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.763 total time=   0.4s
# [CV 5/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 5/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.852 total time=   0.4s
# [CV 1/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 1/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.839 total time=   0.7s
# [CV 2/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 2/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.820 total time=   0.7s
# [CV 3/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 3/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.801 total time=   0.8s
# [CV 4/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 4/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.763 total time=   0.7s
# [CV 5/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 5/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.843 total time=   0.7s
# [CV 1/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 1/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.825 total time=   0.1s
# [CV 2/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 2/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 3/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.801 total time=   0.2s
# [CV 4/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 4/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.754 total time=   0.2s
# [CV 5/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 5/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.814 total time=   0.3s
# [CV 1/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 1/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.829 total time=   0.8s
# [CV 2/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 2/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.796 total time=   0.7s
# [CV 3/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 3/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.806 total time=   0.6s
# [CV 4/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 4/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.777 total time=   0.6s
# [CV 5/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 5/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.838 total time=   0.5s
# [CV 1/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 1/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.825 total time=   1.2s
# [CV 2/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 2/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.810 total time=   0.9s
# [CV 3/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 3/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.806 total time=   0.7s
# [CV 4/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 4/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.768 total time=   0.6s
# [CV 5/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 5/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.852 total time=   1.2s
# [CV 1/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 1/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.829 total time=   0.9s
# [CV 2/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 2/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.825 total time=   0.9s
# [CV 3/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 3/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.796 total time=   0.9s
# [CV 4/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 4/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.758 total time=   0.8s
# [CV 5/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 5/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.838 total time=   0.8s
# [CV 1/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 1/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.844 total time=   0.1s
# [CV 2/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 2/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.825 total time=   0.1s
# [CV 3/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 3/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.815 total time=   0.1s
# [CV 4/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 4/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.773 total time=   0.1s
# [CV 5/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 5/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.848 total time=   0.1s
# [CV 1/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 1/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.825 total time=   0.3s
# [CV 2/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 2/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.825 total time=   0.3s
# [CV 3/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 3/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.820 total time=   0.3s
# [CV 4/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 4/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.763 total time=   0.5s
# [CV 5/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 5/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 1/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 1/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.825 total time=   0.7s
# [CV 2/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 2/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.834 total time=   0.5s
# [CV 3/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 3/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.801 total time=   0.7s
# [CV 4/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 4/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.773 total time=   0.5s
# [CV 5/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 5/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.862 total time=   0.5s
# [CV 1/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 1/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.839 total time=   0.6s
# [CV 2/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 2/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.820 total time=   1.0s
# [CV 3/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 3/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.801 total time=   0.7s
# [CV 4/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 4/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.763 total time=   0.6s
# [CV 5/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 5/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.843 total time=   0.6s
# [CV 1/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 1/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 2/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 2/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.844 total time=   0.1s
# [CV 3/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 3/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.791 total time=   0.1s
# [CV 4/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 4/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.768 total time=   0.2s
# [CV 5/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 5/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.848 total time=   0.3s
# [CV 1/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 1/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.825 total time=   0.5s
# [CV 2/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 2/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.839 total time=   0.3s
# [CV 3/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 3/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.806 total time=   0.3s
# [CV 4/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 4/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.763 total time=   0.3s
# [CV 5/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 5/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.838 total time=   0.3s
# [CV 1/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 1/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.834 total time=   0.7s
# [CV 2/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 2/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.825 total time=   0.5s
# [CV 3/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 3/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.829 total time=   0.5s
# [CV 4/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 4/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.782 total time=   0.5s
# [CV 5/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 5/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.852 total time=   0.5s
# [CV 1/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 1/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.834 total time=   0.7s
# [CV 2/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 2/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.834 total time=   0.7s
# [CV 3/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 3/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.796 total time=   0.9s
# [CV 4/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 4/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.773 total time=   0.7s
# [CV 5/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 5/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.857 total time=   0.7s
# [CV 1/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 1/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.829 total time=   0.3s
# [CV 2/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 2/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 3/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 3/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.777 total time=   0.3s
# [CV 4/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 4/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.754 total time=   0.1s
# [CV 5/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 5/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.833 total time=   0.1s
# [CV 1/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 1/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.834 total time=   0.4s
# [CV 2/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 2/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.810 total time=   0.3s
# [CV 3/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 3/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.801 total time=   0.3s
# [CV 4/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 4/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.749 total time=   0.3s
# [CV 5/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 5/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.857 total time=   0.5s
# [CV 1/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 1/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.825 total time=   0.6s
# [CV 2/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 2/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.820 total time=   0.4s
# [CV 3/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 3/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.820 total time=   0.5s
# [CV 4/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 4/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.773 total time=   1.0s
# [CV 5/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 5/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.848 total time=   0.8s
# [CV 1/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 1/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.834 total time=   1.0s
# [CV 2/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 2/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.820 total time=   1.1s
# [CV 3/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 3/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.810 total time=   0.7s
# [CV 4/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 4/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.768 total time=   0.8s
# [CV 5/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 5/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.848 total time=   0.8s
# [CV 1/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 1/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.815 total time=   0.1s
# [CV 2/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 2/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 3/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 3/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.806 total time=   0.1s
# [CV 4/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 4/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.773 total time=   0.2s
# [CV 5/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 5/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.862 total time=   0.1s
# [CV 1/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 1/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.839 total time=   0.3s
# [CV 2/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 2/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.829 total time=   0.4s
# [CV 3/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 3/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.801 total time=   0.3s
# [CV 4/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 4/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.763 total time=   0.4s
# [CV 5/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 5/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.848 total time=   0.3s
# [CV 1/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 1/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.834 total time=   0.6s
# [CV 2/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 2/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.820 total time=   0.4s
# [CV 3/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 3/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.787 total time=   0.5s
# [CV 4/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 4/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.773 total time=   0.6s
# [CV 5/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 5/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.862 total time=   0.6s
# [CV 1/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 1/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.844 total time=   0.8s
# [CV 2/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 2/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.820 total time=   0.8s
# [CV 3/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 3/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.810 total time=   0.8s
# [CV 4/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 4/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.768 total time=   0.6s
# [CV 5/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 5/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.857 total time=   0.6s
# [CV 1/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 1/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.810 total time=   0.1s
# [CV 2/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 2/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 3/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 3/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 4/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 4/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 5/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 5/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.857 total time=   0.1s
# [CV 1/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 1/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.829 total time=   0.2s
# [CV 2/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 2/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.834 total time=   0.2s
# [CV 3/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 3/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.806 total time=   0.2s
# [CV 4/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 4/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.791 total time=   0.2s
# [CV 5/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 5/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.852 total time=   0.2s
# [CV 1/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 1/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.815 total time=   0.4s
# [CV 2/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 2/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.815 total time=   0.4s
# [CV 3/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 3/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.810 total time=   0.4s
# [CV 4/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 4/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.782 total time=   0.6s
# [CV 5/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 5/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.852 total time=   0.5s
# [CV 1/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 1/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.825 total time=   0.8s
# [CV 2/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 2/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.839 total time=   0.8s
# [CV 3/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 3/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.801 total time=   1.0s
# [CV 4/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 4/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.782 total time=   0.8s
# [CV 5/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 5/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.857 total time=   0.7s
# [CV 1/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 2/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 3/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.806 total time=   0.2s
# [CV 4/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.782 total time=   0.1s
# [CV 5/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.819 total time=   0.1s
# [CV 1/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.825 total time=   0.3s
# [CV 2/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.825 total time=   0.3s
# [CV 3/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.820 total time=   0.3s
# [CV 4/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.782 total time=   0.3s
# [CV 5/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.838 total time=   0.3s
# [CV 1/5; 39/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 39/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.834 total time=   0.5s
# ...
# [CV 1/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.834 total time=   0.3s
# [CV 2/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.820 total time=   0.4s
# [CV 3/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 4/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.777 total time=   0.1s
# [CV 5/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.838 total time=   0.1s
# [CV 1/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.848 total time=   0.3s
# [CV 2/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 3/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.801 total time=   0.3s
# [CV 4/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.810 total time=   0.3s
# [CV 5/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.862 total time=   0.3s
# [CV 1/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.844 total time=   0.5s
# [CV 2/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 2/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.839 total time=   0.5s
# [CV 3/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 3/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.815 total time=   0.5s
# [CV 4/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 4/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.782 total time=   0.5s
# [CV 5/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 5/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.862 total time=   0.6s
# [CV 1/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 1/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.844 total time=   0.8s
# [CV 2/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 2/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.834 total time=   0.7s
# [CV 3/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 3/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.815 total time=   0.7s
# [CV 4/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 4/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.791 total time=   0.8s
# [CV 5/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 5/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.862 total time=   0.8s
# [CV 1/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 1/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.829 total time=   0.1s
# [CV 2/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 2/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.834 total time=   0.1s
# [CV 3/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 3/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.806 total time=   0.1s
# [CV 4/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 4/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 5/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 5/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.867 total time=   0.1s
# [CV 1/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 1/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.848 total time=   0.3s
# [CV 2/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 2/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.829 total time=   0.3s
# [CV 3/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 3/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.820 total time=   0.3s
# [CV 4/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 4/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.801 total time=   0.3s
# [CV 5/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 5/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.862 total time=   0.3s
# [CV 1/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 1/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.839 total time=   0.5s
# [CV 2/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 2/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.825 total time=   1.0s
# [CV 3/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 3/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.810 total time=   1.0s
# [CV 4/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 4/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.787 total time=   0.7s
# [CV 5/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 5/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.862 total time=   0.5s
# [CV 1/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 1/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.829 total time=   0.7s
# [CV 2/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 2/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.834 total time=   0.7s
# [CV 3/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 3/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.810 total time=   0.7s
# [CV 4/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 4/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.787 total time=   0.7s
# [CV 5/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 5/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.857 total time=   0.7s
# [CV 1/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 1/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 2/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 2/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 3/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 3/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.791 total time=   0.1s
# [CV 4/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 4/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 5/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 5/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.833 total time=   0.1s
# [CV 1/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 1/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.839 total time=   0.3s
# [CV 2/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 2/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.839 total time=   0.3s
# [CV 3/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 3/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.815 total time=   0.3s
# [CV 4/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 4/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.791 total time=   0.3s
# [CV 5/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 5/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.862 total time=   0.3s
# [CV 1/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 1/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.844 total time=   0.5s
# [CV 2/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 2/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.829 total time=   0.5s
# [CV 3/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 3/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.810 total time=   0.5s
# [CV 4/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 4/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.791 total time=   0.5s
# [CV 5/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 5/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.867 total time=   0.5s
# [CV 1/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 1/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.825 total time=   0.7s
# [CV 2/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 2/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.820 total time=   0.7s
# [CV 3/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 3/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.806 total time=   0.7s
# [CV 4/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 4/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.801 total time=   0.7s
# [CV 5/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 5/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.843 total time=   0.7s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [3, 5, 8, 11],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 30,
#  'max_features': 'log2',
#  'min_samples_split': 5,
#  'n_estimators': 200}

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 200, max_depth=30 ,
                                 min_samples_split= 3, max_features= 'log2')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.827433628318584

# %%
import joblib
joblib.dump(Final_mod,'Insurance_claims_Final.pkl')
# Out:
# ['Insurance_claims_Final.pkl']
